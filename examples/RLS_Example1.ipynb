# %% [markdown]
# # RLS Example 1
#
# Flat security model: every dimension (country, business unit, salesperson, reduction codes, plus a couple of two-column combinations) restricts independently, with no dependency on record type.

# %% [markdown]
# ### Setup

# %%
workspace = 'DEV_YourWorkspace_Sales'

# %%
dataset = 'Sales'

# %%
# %run Connections

# %%
# %run Email notifications

# %%
# %run RLS_Management_Functions

# %%
workspace_current = workspace

# %% [markdown]
# ### Global filters
#
# Fixed condition AND-ed into ALL standard roles. Empty if not needed.

# %%
global_filters = [
    {
        "table": "Customer",
        "column": "Is_Consolidated",
        "value": "Consolidated"
    },
    # Add more global filters here if needed, e.g.:
    # {
    #     "table": "DV_PBI_Product",
    #     "column": "Is_Active",
    #     "value": "True"
    # },
]

# %% [markdown]
# ### Config
#
# Structure:
# - **Standard dimensions** (`CountryCode`, `Zone`, `Salesperson`, `Reduction14`) — one role per unique value.
# - **Concatenated role** (`BrandingCode_BusinessUnitCode`) — combines two columns into a single role.
# - **`FullAccess`** — full access for flagged users.
# - **`Consolidated`** (`consolidated_default`) — baseline filter applied to ALL users except those already `FullAccess`.

# %%
config = {
    "CountryCode": {
        "table": "Customer",
        "prefix": "RLS_CountryCode",
        "column": "CountryCode"
    },
    "Zone": {
        "table": "Customer",
        "prefix": "RLS_Zone",
        "column": "Zone"
    },
    "BusinessUnitCode_Desc_Master_Company": {
        "table": "Global Dimensions",
        "prefix": "RLS_BusinessUnitCode_Desc_Master_Company",
        "column": "BusinessUnitCode_Desc_Master_Company"
    },
    "BusinessUnitCode_BusinessAppCode": {
        "table": "Global Dimensions",
        "prefix": "RLS_BusinessUnitCode_BusinessAppCode",
        "column": "BusinessUnitCode_BusinessAppCode"
    },
    "Salesperson_CountryCode": {
        "table": "Global Dimensions",
        "prefix": "RLS_Salesperson_CountryCode",
        "column": "Salesperson_CountryCode"
    },
    "CompanyCode_BusinessAppCode": {
        "table": "Global Dimensions",
        "prefix": "RLS_CompanyCode_BusinessAppCode",
        "column": "CompanyCode_BusinessAppCode"
    },
    "TerritoryCode": {
        "table": "Customer",
        "prefix": "RLS_CountryCode",
        "column": "CountryCode"
    },
    "StateCode": {
        "table": "Customer",
        "prefix": "RLS_StateCode",
        "column": "StateCode"
    },
    "BrandingCode": {
        "table": "Product",
        "prefix": "RLS_BrandingCode",
        "column": "BrandingCode"
    },
    "Desc_Master_Company": {
        "table": "Company",
        "prefix": "RLS_Desc_Master_Company",
        "column": "Desc_Master_Company"
    },
    "BusinessUnitCode": {
        "table": "Global Dimensions",
        "prefix": "RLS_BusinessUnitCode",
        "column": "BusinessUnitCode"
    },
    "BusinessAppCode": {
        "table": "Global Dimensions",
        "prefix": "RLS_BusinessAppCode",
        "column": "BusinessAppCode"
    },
    "InternalManager": {
        "table": "Global Dimensions",
        "prefix": "RLS_InternalManager",
        "column": "Desc_Internal_Manager"
    },
    "Salesperson": {
        "table": "Global Dimensions",
        "prefix": "RLS_Salesperson",
        "column": "Desc_Salesperson"
    },
    "CompanyCode": {
        "table": "Global Dimensions",
        "prefix": "RLS_CompanyCode",
        "column": "CompanyCode"
    },
    "Serie": {
        "table": "Product",
        "prefix": "RLS_Serie",
        "column": "Serie"
    },

######### REDUCTIONS


    "Reduction14": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction14",
        "column": "User_Adhoc_RowLevelSecurity4"
    },
    "Reduction17": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction17",
        "column": "User_Adhoc_RowLevelSecurity5"
    },
    "Reduction22": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction22",
        "column": "User_Adhoc_RowLevelSecurity7"
    },
    "Reduction23": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction23",
        "column": "User_Adhoc_RowLevelSecurity8"
    },
    "Reduction24": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction24",
        "column": "User_Adhoc_RowLevelSecurity9"
    },
    "Reduction25": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction25",
        "column": "User_Adhoc_RowLevelSecurity10"
    },
    "Reduction26": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction26",
        "column": "User_Adhoc_RowLevelSecurity11"
    },
    "Reduction27": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction27",
        "column": "User_Adhoc_RowLevelSecurity12"
    },
    "Reduction28": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction28",
        "column": "User_Adhoc_RowLevelSecurity13"
    },
    "Reduction29": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction29",
        "column": "User_Adhoc_RowLevelSecurity14"
    },
    "Reduction30": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction30",
        "column": "User_Adhoc_RowLevelSecurity15"
    },
    "Reduction31": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction31",
        "column": "User_Adhoc_RowLevelSecurity16"
    },
    "Reduction32": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction32",
        "column": "User_Adhoc_RowLevelSecurity17"
    },
    "Reduction33": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction33",
        "column": "User_Adhoc_RowLevelSecurity18"
    },
    "Reduction34": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction34",
        "column": "User_Adhoc_RowLevelSecurity19"
    },
    "Reduction35": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction35",
        "column": "User_Adhoc_RowLevelSecurity20"
    },
    "Reduction36": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction36",
        "column": "User_Adhoc_RowLevelSecurity21"
    },
    "Reduction37": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction37",
        "column": "User_Adhoc_RowLevelSecurity22"
    },
    "Reduction38": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction38",
        "column": "User_Adhoc_RowLevelSecurity23"
    },
    "Reduction39": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction39",
        "column": "User_Adhoc_RowLevelSecurity24"
    },
    "Reduction40": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction40",
        "column": "User_Adhoc_RowLevelSecurity25"
    },
    "Reduction41": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction41",
        "column": "User_Adhoc_RowLevelSecurity26"
    },
    "Reduction44": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction44",
        "column": "User_Adhoc_RowLevelSecurity29"
    },
    "Reduction45": {
        "table": "Global Dimensions",
        "prefix": "RLS_Reduction45",
        "column": "User_Adhoc_RowLevelSecurity30"
    },

    # ── CONCATENATED ROLES ────────────────────────────────────────────────────

    "BrandingCode_BusinessUnitCode": {
        "prefix": "RLS_BrandingCode_BusinessUnitCode",
        "concatenated_from": {
            "BrandingCode": {"table": "Product",           "column": "BrandingCode"},
            "BusinessUnitCode":  {"table": "Global Dimensions", "column": "BusinessUnitCode"}
        }
    },

    "CompanyCode_Platform": {
        "prefix": "RLS_CompanyCode_Platform",
        "concatenated_from": {
            "CompanyCode":  {"table": "Global Dimensions", "column": "CompanyCode"},
            "Platform": {"table": "Global Dimensions", "column": "Platform"}
        }
    },

    "Industry_BusinessUnitCode": {
        "prefix": "RLS_Industry_BusinessUnitCode",
        "concatenated_from": {
            "Industry":  {"table": "Global Dimensions", "column": "Industry"},
            "BusinessUnitCode": {"table": "Global Dimensions", "column": "BusinessUnitCode"}
        }
    },

    # ── SPECIAL ROLES ─────────────────────────────────────────────────────────
    "FullAccess": {
        "table": None,          
        "prefix": "RLS_FullAccess",
        "column": None,          
        "special": "full_access",
        "source_column": "FullAccess",   
        "source_value": "ALL"          
    },
    "Consolidated": {
        "table": "Customer",
        "prefix": "RLS_Consolidated",
        "column": "Is_Consolidated",
        "special": "consolidated",
        "source_column": "Is_Consolidated",
        "source_value": "Consolidated",
        "fixed_filter": '[Is_Consolidated] = "Consolidated"',
        "ignore_cols": ["PK", "Username", "FullAccess", "Is_Consolidated", "model_upn", "User_ID"]  # ← add model_upn here
    },
}

# %% [markdown]
# ### RLS Table
#
# Loads the security source table and applies concatenated-role preprocessing.

# %%
source_path = path_rls
source_table = 'RLS_Sales'

df = spark.read.format("delta").load(f"{source_path}{source_table}")

# %% [markdown]
# ### AD Users join (UPN validation)

# %%
source_path = path_bronze
source_table = 'ad_userslicences'

df_ad = spark.read.format("delta").load(f"{source_path}{source_table}").select(
    F.col('UserPrincipalName').alias('Username'),
    F.col('UserId').alias('User_ID')
)


#### USER VALIDATION
df = df.join(df_ad, on = 'Username', how='inner')
df = df.where(F.col('User_ID').isNotNull())

# %% [markdown]
# ## RUN

# %%
df, config = preprocess_concatenated_roles(df, config)

# %% [markdown]
# #### 1. Create/update roles

# %%
create_or_replace_roles_v3(config, dataset, workspace, global_filters, rls=df)

# %% [markdown]
# #### 2. Clean up unused roles

# %%
#drop_unused_roles(config, dataset, workspace, rls=df)

# %% [markdown]
# #### 3. Sync membership (delta, with audit)

# %%
result, summary = run_with_audit(
    update_members_delta,
    dataset=dataset,
    config=config,      
    workspace=workspace,
    env=env,
    rls=df,
    chunk_size=1000,               # large initial load (~21k) — validate in DEV before promoting to prod
    alert_threshold=0.05,
    critical_drop_threshold=0.5,
    audit_path=path_control,     # from Connections — leave as None to use the notebook's default lakehouse
    alert_to="your-team@yourcompany.com",
    skip_members=[]
)
